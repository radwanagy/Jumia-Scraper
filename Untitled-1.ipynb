# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import csv


# إعداد الخيارات
options = Options()
options.add_argument("--start-maximized")  # يبدأ المتصفح بوضع ملئ الشاشة

# إعداد الخدمة بمسار chromedriver
service = Service(r"C:\Users\radwa\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")

# إنشاء المتصفح
driver = webdriver.Chrome(service=service, options=options)


# إنهاء الجلسة
#driver.quit()

# %%
driver.get("https://www.jumia.com.eg/catalog/?q=samsung+a16")

# %%
cards=driver.find_elements("xpath","//a[@ class='core']")

# %%
with open("prodcts_of_jumia.csv",mode="w",newline="",encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Title", "Image URL", "Price", "Rating"])
    for card in cards :
        try:
          title=driver.find_element("xpath", ".//h3[@class='name']")
        except:
          title="Not Found"  
        try:
          price=driver.find_element("xpath", ".//dev[@class='prc']")
        except:
          price="Not Found" 
        try:
          image_url=driver.find_element("xpath", ".//img[@class='img']").get_attribute("src")
        except:
          image_url="Not Found"
        try:
          Rating=driver.find_element("xpath", ".//dev[@class='n']")
        except:
          Rating="Not Found"    
    
        writer.writerow([title, image_url, price, Rating])

driver.quit()

# %%
with open("prodcts_of_jumia.csv", mode="r", encoding="utf-8") as file:
    content = file.read()
    print(content)
# Out:
# Title,Image URL,Price,Rating
# "<selenium.webdriver.remote.webelement.WebElement (session=""435ee6b1b7628c60959b67033b68ab19"", element=""f.FA44D543DF728B47148CBD29BDEA0B04.d.0D106A2DC6D9DABE38304FAD3E135D84.e.177"")>",https://eg.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/16/8798421/1.jpg?7634,Not Found,Not Found
# "<selenium.webdriver.remote.webelement.WebElement (session=""435ee6b1b7628c60959b67033b68ab19"", element=""f.FA44D543DF728B47148CBD29BDEA0B04.d.0D106A2DC6D9DABE38304FAD3E135D84.e.177"")>",https://eg.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/16/8798421/1.jpg?7634,Not Found,Not Found
# "<selenium.webdriver.remote.webelement.WebElement (session=""435ee6b1b7628c60959b67033b68ab19"", element=""f.FA44D543DF728B47148CBD29BDEA0B04.d.0D106A2DC6D9DABE38304FAD3E135D84.e.177"")>",https://eg.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/16/8798421/1.jpg?7634,Not Found,Not Found
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\radwa\\AppData\\Local\\Programs\\Microsoft VS Code'
